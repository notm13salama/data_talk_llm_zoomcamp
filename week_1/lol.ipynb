# %%
from openai import OpenAI
from pprint import pprint

gemini_api_key = "AIzaSyACYCkqnwc4j6UU2xACdhqemPeFtTlgG64"

client = OpenAI(
    api_key= gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

m = "gemini-2.5-flash-preview-05-20"
response = client.chat.completions.create(
    model="gemini-2.5-flash-preview-05-20",
    reasoning_effort= None,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Explain to me how AI works"
        }
    ]
)

pprint(response.choices[0].message.content)
# Out:
# ("That's a great question, and it's less complicated than many people imagine! "
#  "At its core, AI isn't magic; it's a field of computer science focused on "
#  'creating systems that can perform tasks that would normally require human '
#  'intelligence.\n'
#  '\n'
#  'The most common and impactful form of AI today is **Machine Learning (ML)**. '
#  "Let's break down how it generally works using a simple analogy:\n"
#  '\n'
#  '**Imagine you want to teach a computer to identify a cat in a picture.**\n'
#  '\n'
#  '### The Core Idea: Learning from Data\n'
#  '\n'
#  'Instead of explicitly telling the computer "A cat has two pointy ears, a '
#  'tail, whiskers, and fur," you show it thousands, even millions, of '
#  'examples.\n'
#  '\n'
#  "Here's the general process:\n"
#  '\n'
#  '1.  **Data Collection (The "Textbook")**\n'
#  '    *   You gather a massive amount of data: in our example, thousands of '
#  'images, some with cats, some without.\n'
#  '    *   Crucially, you **label** this data. For each image, you tell the '
#  'computer: "This one IS a cat," or "This one is NOT a cat." (Or even more '
#  'detailed labels like "Siamese cat," "Persian cat," etc.)\n'
#  '    *   **Why it matters:** The quality and quantity of this labeled data '
#  'are paramount. Garbage in, garbage out!\n'
#  '\n'
#  '2.  **The Algorithm/Model (The "Student\'s Brain" or "Learning Strategy")**\n'
#  '    *   This is the computer program designed to learn from the data. There '
#  'are many different types of algorithms (e.g., neural networks, decision '
#  'trees, support vector machines).\n'
#  "    *   **What it does:** It's designed to find patterns, correlations, and "
#  'relationships within the data. It doesn\'t "know" what a cat is, but it can '
#  'find statistical features that are common in cat pictures and uncommon in '
#  'non-cat pictures.\n'
#  '\n'
#  '3.  **Training (The "Studying")**\n'
#  '    *   You feed your labeled data into the chosen algorithm.\n'
#  '    *   The algorithm processes these images, trying to figure out what '
#  'common features distinguish "cat" images from "non-cat" images.\n'
#  '    *   It makes an initial guess ("I think this is a cat because it has '
#  'pointy things").\n'
#  '    *   You then tell it if its guess was right or wrong based on your '
#  'labels.\n'
#  '    *   If it was wrong, the algorithm **adjusts its internal "settings" or '
#  '"parameters"** slightly, trying to get closer to the correct answer next '
#  'time.\n'
#  '    *   This process of guessing, getting feedback, and adjusting repeats '
#  "millions or billions of times across the entire dataset. It's like a student "
#  'doing practice problems, getting them graded, and learning from their '
#  'mistakes.\n'
#  '\n'
#  '4.  **Prediction/Decision (The "Answering Questions")**\n'
#  '    *   Once the training is complete, the algorithm (now called a "model" '
#  'because it has learned) is ready.\n'
#  '    *   You give it a **new, unseen image** – one it has never encountered '
#  'during training.\n'
#  '    *   The model applies all the patterns and rules it learned during '
#  'training and makes a prediction: "I am X% confident that this image contains '
#  'a cat."\n'
#  '\n'
#  '5.  **Feedback & Refinement (The "Getting Grades & Improving")**\n'
#  '    *   Even after deployment, models can often be further refined. If they '
#  'make a wrong prediction in the real world, that new data point (with the '
#  'correct answer) can be fed back into the system to help it learn and improve '
#  'over time.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### Why is AI (specifically Machine Learning) so powerful now?\n'
#  '\n'
#  '*   **Massive Data:** We generate unprecedented amounts of digital data '
#  'every second.\n'
#  '*   **Incredible Computing Power:** Modern computers (especially with '
#  'specialized hardware like GPUs) can process this data and perform the '
#  'complex calculations needed for training very quickly.\n'
#  '*   **Improved Algorithms:** Researchers have developed more sophisticated '
#  'and efficient algorithms, particularly in the field of **Deep Learning** (a '
#  'subset of Machine Learning that uses neural networks with many "layers" to '
#  'find very complex patterns).\n'
#  '\n'
#  '### Types of AI (Beyond just cat pictures):\n'
#  '\n'
#  'While the core principle of learning from data remains, AI manifests in many '
#  'ways:\n'
#  '\n'
#  '*   **Natural Language Processing (NLP):** Understanding, interpreting, and '
#  'generating human language (e.g., chatbots like me, translation services, '
#  'spam filters, sentiment analysis).\n'
#  '*   **Computer Vision:** Enabling computers to "see" and interpret visual '
#  'information (e.g., facial recognition, self-driving cars, medical image '
#  'analysis).\n'
#  '*   **Reinforcement Learning:** AI learns by interacting with an environment '
#  'and receiving rewards or penalties (e.g., AI that learns to play complex '
#  'games like Chess or Go, controlling robots).\n'
#  '*   **Expert Systems:** Older form of AI based on explicit rules and '
#  'knowledge provided by human experts.\n'
#  '\n'
#  '### What AI is NOT:\n'
#  '\n'
#  '*   **Conscious or Sentient:** Modern AI does not "think" or "feel" in the '
#  "human sense. It's executing complex mathematical operations based on "
#  'patterns it has found.\n'
#  "*   **Magical:** It's built on logic, mathematics, and statistics.\n"
#  '*   **Omniscient:** It only knows what it has been trained on and can make '
#  'mistakes, especially when encountering data outside its training '
#  'distribution.\n'
#  '\n'
#  'In essence, AI works by enabling computers to **learn from experience '
#  '(data)**, identify patterns, and make predictions or decisions based on '
#  'those patterns, rather than being explicitly programmed for every single '
#  'scenario.')

# %%
from minsearch import Index

# Create documents
docs = [
    {
        "question": "How do I join the course after it has started?",
        "text": "You can join the course at any time. We have recordings available.",
        "section": "General Information",
        "course": "data-engineering-zoomcamp"
    },
    {
        "question": "What are the prerequisites for the course?",
        "text": "You need to have basic knowledge of programming.",
        "section": "Course Requirements",
        "course": "data-engineering-zoomcamp"
    }
]

# Create and fit the index
index = Index(
    text_fields=["question", "text", "section"],
    keyword_fields=["course"]
)
index.fit(docs)

# Search with filters and boosts
query = "Can I join the course if it has already started?"
filter_dict = {"course": "data-engineering-zoomcamp"}
boost_dict = {"question": 3, "text": 1, "section": 1}

results = index.search(query, filter_dict=filter_dict, boost_dict=boost_dict)

# %%
results
# Out:
# [{'question': 'How do I join the course after it has started?',
#   'text': 'You can join the course at any time. We have recordings available.',
#   'section': 'General Information',
#   'course': 'data-engineering-zoomcamp'},
#  {'question': 'What are the prerequisites for the course?',
#   'text': 'You need to have basic knowledge of programming.',
#   'section': 'Course Requirements',
#   'course': 'data-engineering-zoomcamp'}]
